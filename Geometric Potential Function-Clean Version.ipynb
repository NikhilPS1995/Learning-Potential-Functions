# %%
# Import necessary modules

import os
import sys
import numpy as np
import math
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import matplotlib.pyplot as plt

import torch.nn.functional as F

# %%
need_pytorch3d=False
try:
    import pytorch3d
except ModuleNotFoundError:
    need_pytorch3d=True
if need_pytorch3d:
    if torch.__version__.startswith("2.1.") and sys.platform.startswith("linux"):
        # We try to install PyTorch3D via a released wheel.
        pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
        version_str="".join([
            f"py3{sys.version_info.minor}_cu",
            torch.version.cuda.replace(".",""),
            f"_pyt{pyt_version_str}"
        ])
        # !pip install fvcore iopath
        # !pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html
    else:
        # We try to install PyTorch3D from source.
        # !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'
import os
import torch

from pytorch3d.transforms.so3 import (
    so3_exp_map,
    so3_relative_angle,
    so3_log_map,
)

# %%
# Input Convex Neural Network

class ICNN(nn.Module):
    def __init__(self, layer_sizes, activation=F.relu_):
        super().__init__()
        
        self.W = nn.ParameterList([nn.Parameter(torch.Tensor(l, layer_sizes[0]**2)) 
                                   for l in layer_sizes[1:]])
        self.U = nn.ParameterList([nn.Parameter(torch.Tensor(layer_sizes[i+1], layer_sizes[i]))
                                   for i in range(1,len(layer_sizes)-1)])
        self.bias = nn.ParameterList([nn.Parameter(torch.Tensor(l)) for l in layer_sizes[1:]])
        self.act = activation
        self.reset_parameters()
        

    def reset_parameters(self):
        # copying from PyTorch Linear
        for W in self.W:
            nn.init.kaiming_uniform_(W, a=5**0.5)
        for U in self.U:
            nn.init.kaiming_uniform_(U, a=5**0.5)
        for i,b in enumerate(self.bias):
            fan_in, _ = nn.init._calculate_fan_in_and_fan_out(self.W[i])
            bound = 1 / (fan_in**0.5)
            nn.init.uniform_(b, -bound, bound)
        
#         for p in model.parameters():
#             p.data.fill_(0)

    def forward(self, x):
        # Reshape the 3x3 matrix x into a vector to obtain the trace tr[Wx]+b
        xr = torch.reshape(x,(-1,))
        z = F.linear(xr, self.W[0], self.bias[0])
        z = self.act(z)

        for W,b,U in zip(self.W[1:-1], self.bias[1:-1], self.U[:-1]):
            z = F.linear(xr, W, b) + F.linear(z, F.softplus(U)) / U.shape[0]
            z = self.act(z)

        return F.linear(xr, self.W[-1], self.bias[-1]) + F.linear(z, F.softplus(self.U[-1])) / self.U[-1].shape[0]

# Rectified Huber unit - modified ReLU to make it smooth    
class ReHU(nn.Module):
    """ Rectified Huber unit"""
    def __init__(self, d):
        super().__init__()
        self.a = 1/d
        self.b = -d/2

    def forward(self, x):
        return torch.max(torch.clamp(torch.sign(x)*self.a/2*x**2,min=0,max=-self.b),x+self.b)

# Adding a quadratic term to make it PSD    
class MakePSD(nn.Module):
    def __init__(self, f, n, eps=0.01, d=1.0, w1 = 1.0, w2 = 1.0):
        super().__init__()
        self.f = f
        self.zero = nn.Parameter(f(torch.eye(3, dtype = torch.float32)), requires_grad=False)
        self.eps = eps
        self.d = d
        self.rehu = ReHU(self.d)
        self.w1 = w1
        self.w2 = w2

    def forward(self, x):
        smoothed_output = self.rehu(self.f(x) - self.zero)
        quadratic_under = self.eps*torch.trace(torch.eye(3, dtype = torch.float32)-x) #self.eps*(x**2).sum(1,keepdim=True)
        
        '''
        w1 and w2 are weights on the output and the quadratic term.
        w1 = 0 makes the output the Frobenius norm eps*tr[I - Rd'*R]
        '''
    
        return self.w1*smoothed_output + self.w2*quadratic_under



def configure():

    lsd = 3
    ph_dim = 14 #16 
    
    V = MakePSD(ICNN([lsd, ph_dim, ph_dim, ph_dim, 1], activation=ReHU(0.01)), lsd, eps = 0.01, d = 1.0, w1 = 1, w2 = 1)
    

    #V = nn.Sequential(nn.Linear(lsd, ph_dim, bias=False), nn.LeakyReLU(),
    #    nn.Linear(ph_dim, lsd, bias=False), nn.LeakyReLU(),
    #    PosDefICNN([lsd, ph_dim, ph_dim, 1], eps=projfn_eps, negative_slope=0.3))

    
    global potentialFunction
    potentialFunction = V

# %%
class Dynamics(nn.Module):
    
    def __init__(self, differentiable_model, J =  torch.eye(3, dtype = torch.float32), Kd = torch.eye(3, dtype = torch.float32), Rd = torch.eye(3, dtype = torch.float32), nSim = 100, dt = 0.1):
        super().__init__()

        self.differentiable_model = differentiable_model # Potential Function
        self.J = J # Inertia Tensor
        self.Kd = Kd # Damping matrix
        self.Rd = Rd # Desired final orientation
        self.nSim = nSim #number of euler forward steps
        self.dt = dt # sampling time
        
    def proportionalControl(self, R):
        
        '''
        R is the current rotaton matrix state
        Rd is the desired rotation matrix 
        '''
        
        '''
        create a lie algebra element eta and move along eta by eps
        take limit eps --> 0
        differentiate wrt eta to obtain the gradient (should be the same for any eta) 
        
        '''

        
        # epsilon for obtaining the limit for a small variation
        eps = torch.tensor(0.0, dtype = torch.float32, requires_grad = True)
        
        # direction (lie algebra element) along which the variation is taken
        #eta = torch.randn(1, 3, dtype=torch.float32, requires_grad = True)
        
        eta = torch.tensor([[1.0, 1.0, 1.0]], dtype = torch.float32, requires_grad = True)
        
        # geometrically consistent variation
        delta_R = so3_exp_map(eta*eps)[0]
        
        # y+dy 
        y = self.differentiable_model(0.5*(self.Rd.permute(1,0)@R@delta_R+delta_R.permute(1,0)@R.permute(1,0)@self.Rd)) # traditional forward pass
        
        # lt eps -> 0 ((y+dy)(eps) - y)/ eps
        dydeps = autograd.grad(y, eps , create_graph = True)[0]
        
        # grad_eta (dy.eta) = dy
        d1Phi = autograd.grad(dydeps, eta, create_graph = True)[0]

        return -d1Phi.permute(1,0)
    
    def derivativeControl(self, R, omega):
        
        dControl = -self.Kd@omega
        
        return dControl
    
    def dynamicalModel(self, R, omega, T):

        # Angular Velocity at next step
        omegaPlus = omega + torch.linalg.inv(self.J)@(torch.linalg.cross(self.J@omega,omega,dim = 0) + T) * self.dt
        
        # rotation matrix at next step
        RPlus = R@so3_exp_map(omega.permute(1,0)*self.dt)[0]
        
        return RPlus,omegaPlus
    
    def forward(self, R0, omega0):
        
        '''
        Forward function integrates the dynamics forward using dynamicalModel function 
        and obtains the trajectory for nSim time steps. 
        The trajectory consists of the rotation matrix R and the angular velocity vector omega
        at different time steps
        '''
        
        R,omega = {},{}
    
        R['e0'] = R0
        omega['e0'] = omega0
    
    
        for i in range(self.nSim-1):
        
            T = self.proportionalControl(R['e'+str(i)]) + self.derivativeControl(R['e'+str(i)], omega['e'+str(i)])
            
            R['e'+str(i+1)], omega['e'+str(i+1)] = self.dynamicalModel(R['e'+str(i)], omega['e'+str(i)], T)
            

        return R, omega
    
    
def loss(RPredicted, RDesired, omegaPredicted,  omegaDesired, w_R, w_omega):
    
    l = {}
    for key0 in RPredicted:
        for key1 in RPredicted[key0]:
            l[key0+key1] = w_R*torch.norm(RPredicted[key0][key1]-RDesired[key0][key1])**2+w_omega*torch.norm(omegaPredicted[key0][key1]-omegaDesired[key0][key1])**2
    
    return sum(l.values())

# %%
configure()

# Inertia Tensor
J = torch.diag(torch.tensor([1.0,1.0,1.0], dtype = torch.float32, requires_grad = False))
nSim = 50
dt = 0.2
Kd = torch.diag(torch.tensor([1.0,1.0,1.0], dtype = torch.float32, requires_grad = False))
RDes = torch.eye(3, dtype = torch.float32, requires_grad = False)
omegaDes = torch.zeros(3,1, dtype = torch.float32, requires_grad = False)

model = Dynamics(potentialFunction, J, Kd, RDes, nSim, dt)

# %%
# Generating nData number of initial states
nData = 50

R0_Data = torch.zeros(3,3,nData, dtype = torch.float32)
omega0_Data = torch.zeros(3,1,nData, dtype = torch.float32)


for i in range(nData):
    R0_Data[:,:,i] = so3_exp_map(torch.randn(1,3, dtype = torch.float32))[0]
    omega0_Data[:,:,i] = torch.randn(3,1, dtype = torch.float32)
    
R0_Data.requires_grad = True
omega0_Data.requires_grad = True

# %%
RDesTraj, omegaDesTraj = {},{} 

for i in range(nSim):
    RDesTraj['e'+str(i)] = RDes
    omegaDesTraj['e'+str(i)] = omegaDes
    RDesTraj['e'+str(i)].requires_grad = True
    omegaDesTraj['e'+str(i)].requires_grad = True

# %%
learning_rate = 0.01
n_iters = 10
optimizer = optim.Adam(model.parameters() , lr = learning_rate)
w_R = 1.0
w_omega = 1.0


for epochs in range(n_iters):

    
    RPredicted = {}
    omegaPredicted = {}
    
    RDesired = {}
    omegaDesired = {}
    
    l1 = {}
    
    for j in range(nData):
        RPredicted['e'+str(j)], omegaPredicted['e'+str(j)] = model(R0_Data[:,:,j], omega0_Data[:,:,j])
        RDesired['e'+str(j)], omegaDesired['e'+str(j)] = RDesTraj, omegaDesTraj
    
    l = loss(RPredicted, RDesired,omegaPredicted, omegaDesired, w_R, w_omega)/nData
    
    #print(l)

    
    # gradients = backward pass
    l.backward(retain_graph=True)
    
    #with torch.no_grad():
    #    w-= learning_rate*w.grad
    
    # instead 
    optimizer.step()
        
    # zero gradients
    #w.grad.zero_()
    optimizer.zero_grad()
    
    if epochs%1==0:
        print('epoch number',epochs,',loss = ', l)
# Out:
# epoch number 0 ,loss =  tensor(102.2509, grad_fn=<DivBackward0>)
# epoch number 1 ,loss =  tensor(101.9403, grad_fn=<DivBackward0>)
# epoch number 2 ,loss =  tensor(92.8759, grad_fn=<DivBackward0>)
# epoch number 3 ,loss =  tensor(93.9472, grad_fn=<DivBackward0>)
# epoch number 4 ,loss =  tensor(83.6771, grad_fn=<DivBackward0>)
# epoch number 5 ,loss =  tensor(79.4138, grad_fn=<DivBackward0>)
# epoch number 6 ,loss =  tensor(67.6307, grad_fn=<DivBackward0>)
# epoch number 7 ,loss =  tensor(64.3355, grad_fn=<DivBackward0>)
# epoch number 8 ,loss =  tensor(61.9825, grad_fn=<DivBackward0>)
# epoch number 9 ,loss =  tensor(62.7670, grad_fn=<DivBackward0>)
# epoch number 10 ,loss =  tensor(58.1304, grad_fn=<DivBackward0>)
# epoch number 11 ,loss =  tensor(57.6623, grad_fn=<DivBackward0>)
# epoch number 12 ,loss =  tensor(56.8375, grad_fn=<DivBackward0>)
# epoch number 13 ,loss =  tensor(56.5227, grad_fn=<DivBackward0>)
# epoch number 14 ,loss =  tensor(56.4779, grad_fn=<DivBackward0>)
# epoch number 15 ,loss =  tensor(56.6011, grad_fn=<DivBackward0>)
# epoch number 16 ,loss =  tensor(56.5306, grad_fn=<DivBackward0>)
# epoch number 17 ,loss =  tensor(56.3203, grad_fn=<DivBackward0>)
# epoch number 18 ,loss =  tensor(55.9928, grad_fn=<DivBackward0>)
# epoch number 19 ,loss =  tensor(55.5165, grad_fn=<DivBackward0>)
# epoch number 20 ,loss =  tensor(55.2984, grad_fn=<DivBackward0>)
# epoch number 21 ,loss =  tensor(55.1418, grad_fn=<DivBackward0>)
# epoch number 22 ,loss =  tensor(55.0650, grad_fn=<DivBackward0>)
# epoch number 23 ,loss =  tensor(54.8651, grad_fn=<DivBackward0>)
# epoch number 24 ,loss =  tensor(54.5208, grad_fn=<DivBackward0>)
# epoch number 25 ,loss =  tensor(54.3552, grad_fn=<DivBackward0>)
# epoch number 26 ,loss =  tensor(54.4205, grad_fn=<DivBackward0>)
# epoch number 27 ,loss =  tensor(54.3940, grad_fn=<DivBackward0>)
# epoch number 28 ,loss =  tensor(54.1918, grad_fn=<DivBackward0>)
# epoch number 29 ,loss =  tensor(54.0267, grad_fn=<DivBackward0>)
# epoch number 30 ,loss =  tensor(53.7965, grad_fn=<DivBackward0>)
# epoch number 31 ,loss =  tensor(53.4732, grad_fn=<DivBackward0>)
# epoch number 32 ,loss =  tensor(53.2311, grad_fn=<DivBackward0>)
# epoch number 33 ,loss =  tensor(53.2587, grad_fn=<DivBackward0>)
# epoch number 34 ,loss =  tensor(53.1841, grad_fn=<DivBackward0>)
# epoch number 35 ,loss =  tensor(52.9872, grad_fn=<DivBackward0>)
# epoch number 36 ,loss =  tensor(53.1053, grad_fn=<DivBackward0>)
# epoch number 37 ,loss =  tensor(52.8894, grad_fn=<DivBackward0>)
# epoch number 38 ,loss =  tensor(52.9375, grad_fn=<DivBackward0>)
# epoch number 39 ,loss =  tensor(52.9784, grad_fn=<DivBackward0>)
# epoch number 40 ,loss =  tensor(53.0679, grad_fn=<DivBackward0>)
# epoch number 41 ,loss =  tensor(53.0022, grad_fn=<DivBackward0>)
# epoch number 42 ,loss =  tensor(53.0860, grad_fn=<DivBackward0>)
# epoch number 43 ,loss =  tensor(52.9379, grad_fn=<DivBackward0>)
# epoch number 44 ,loss =  tensor(52.8930, grad_fn=<DivBackward0>)
# epoch number 45 ,loss =  tensor(52.8207, grad_fn=<DivBackward0>)
# epoch number 46 ,loss =  tensor(52.6869, grad_fn=<DivBackward0>)
# epoch number 47 ,loss =  tensor(52.6174, grad_fn=<DivBackward0>)
# epoch number 48 ,loss =  tensor(52.5165, grad_fn=<DivBackward0>)
# epoch number 49 ,loss =  tensor(52.5305, grad_fn=<DivBackward0>)
# epoch number 50 ,loss =  tensor(52.5448, grad_fn=<DivBackward0>)
# epoch number 51 ,loss =  tensor(52.6037, grad_fn=<DivBackward0>)
# epoch number 52 ,loss =  tensor(52.4870, grad_fn=<DivBackward0>)
# epoch number 53 ,loss =  tensor(52.4326, grad_fn=<DivBackward0>)
# epoch number 54 ,loss =  tensor(52.4124, grad_fn=<DivBackward0>)
# epoch number 55 ,loss =  tensor(52.4816, grad_fn=<DivBackward0>)
# epoch number 56 ,loss =  tensor(52.4344, grad_fn=<DivBackward0>)
# epoch number 57 ,loss =  tensor(52.3305, grad_fn=<DivBackward0>)
# epoch number 58 ,loss =  tensor(52.2987, grad_fn=<DivBackward0>)
# epoch number 59 ,loss =  tensor(52.2126, grad_fn=<DivBackward0>)
# epoch number 60 ,loss =  tensor(52.1075, grad_fn=<DivBackward0>)
# epoch number 61 ,loss =  tensor(52.1280, grad_fn=<DivBackward0>)
# epoch number 62 ,loss =  tensor(52.1713, grad_fn=<DivBackward0>)
# epoch number 63 ,loss =  tensor(52.2821, grad_fn=<DivBackward0>)
# epoch number 64 ,loss =  tensor(52.3237, grad_fn=<DivBackward0>)
# epoch number 65 ,loss =  tensor(52.3730, grad_fn=<DivBackward0>)
# epoch number 66 ,loss =  tensor(52.2051, grad_fn=<DivBackward0>)
# epoch number 67 ,loss =  tensor(52.0943, grad_fn=<DivBackward0>)
# epoch number 68 ,loss =  tensor(51.9937, grad_fn=<DivBackward0>)
# epoch number 69 ,loss =  tensor(52.0207, grad_fn=<DivBackward0>)
# epoch number 70 ,loss =  tensor(52.0231, grad_fn=<DivBackward0>)
# epoch number 71 ,loss =  tensor(52.0369, grad_fn=<DivBackward0>)
# epoch number 72 ,loss =  tensor(51.9928, grad_fn=<DivBackward0>)
# epoch number 73 ,loss =  tensor(51.9264, grad_fn=<DivBackward0>)
# epoch number 74 ,loss =  tensor(51.9375, grad_fn=<DivBackward0>)
# epoch number 75 ,loss =  tensor(51.9387, grad_fn=<DivBackward0>)
# epoch number 76 ,loss =  tensor(51.8845, grad_fn=<DivBackward0>)
# epoch number 77 ,loss =  tensor(51.8067, grad_fn=<DivBackward0>)
# epoch number 78 ,loss =  tensor(51.7419, grad_fn=<DivBackward0>)
# epoch number 79 ,loss =  tensor(51.6620, grad_fn=<DivBackward0>)
# epoch number 80 ,loss =  tensor(51.7486, grad_fn=<DivBackward0>)
# epoch number 81 ,loss =  tensor(51.7225, grad_fn=<DivBackward0>)
# epoch number 82 ,loss =  tensor(51.6214, grad_fn=<DivBackward0>)
# epoch number 83 ,loss =  tensor(51.6332, grad_fn=<DivBackward0>)
# epoch number 84 ,loss =  tensor(51.8959, grad_fn=<DivBackward0>)
# epoch number 85 ,loss =  tensor(51.9377, grad_fn=<DivBackward0>)
# epoch number 86 ,loss =  tensor(51.9468, grad_fn=<DivBackward0>)
# epoch number 87 ,loss =  tensor(51.8796, grad_fn=<DivBackward0>)
# epoch number 88 ,loss =  tensor(51.8036, grad_fn=<DivBackward0>)
# epoch number 89 ,loss =  tensor(51.7265, grad_fn=<DivBackward0>)
# epoch number 90 ,loss =  tensor(51.8420, grad_fn=<DivBackward0>)
# epoch number 91 ,loss =  tensor(51.9581, grad_fn=<DivBackward0>)
# epoch number 92 ,loss =  tensor(51.9484, grad_fn=<DivBackward0>)
# epoch number 93 ,loss =  tensor(51.8681, grad_fn=<DivBackward0>)
# epoch number 94 ,loss =  tensor(51.7924, grad_fn=<DivBackward0>)
# epoch number 95 ,loss =  tensor(51.6373, grad_fn=<DivBackward0>)
# epoch number 96 ,loss =  tensor(51.6452, grad_fn=<DivBackward0>)
# epoch number 97 ,loss =  tensor(51.7468, grad_fn=<DivBackward0>)
# epoch number 98 ,loss =  tensor(51.6925, grad_fn=<DivBackward0>)
# epoch number 99 ,loss =  tensor(51.7084, grad_fn=<DivBackward0>)
# epoch number 100 ,loss =  tensor(51.7051, grad_fn=<DivBackward0>)
# epoch number 101 ,loss =  tensor(51.7372, grad_fn=<DivBackward0>)
# epoch number 102 ,loss =  tensor(51.6684, grad_fn=<DivBackward0>)
# epoch number 103 ,loss =  tensor(51.6784, grad_fn=<DivBackward0>)
# epoch number 104 ,loss =  tensor(51.7791, grad_fn=<DivBackward0>)
# epoch number 105 ,loss =  tensor(51.7438, grad_fn=<DivBackward0>)
# epoch number 106 ,loss =  tensor(51.7049, grad_fn=<DivBackward0>)
# epoch number 107 ,loss =  tensor(51.8169, grad_fn=<DivBackward0>)
# epoch number 108 ,loss =  tensor(51.6779, grad_fn=<DivBackward0>)
# epoch number 109 ,loss =  tensor(51.6820, grad_fn=<DivBackward0>)
# epoch number 110 ,loss =  tensor(51.6054, grad_fn=<DivBackward0>)
# epoch number 111 ,loss =  tensor(51.6074, grad_fn=<DivBackward0>)
# epoch number 112 ,loss =  tensor(51.7371, grad_fn=<DivBackward0>)
# epoch number 113 ,loss =  tensor(51.7708, grad_fn=<DivBackward0>)
# epoch number 114 ,loss =  tensor(51.7898, grad_fn=<DivBackward0>)
# epoch number 115 ,loss =  tensor(51.6918, grad_fn=<DivBackward0>)
# epoch number 116 ,loss =  tensor(51.6741, grad_fn=<DivBackward0>)
# epoch number 117 ,loss =  tensor(51.8359, grad_fn=<DivBackward0>)
# epoch number 118 ,loss =  tensor(51.8024, grad_fn=<DivBackward0>)
# epoch number 119 ,loss =  tensor(51.8247, grad_fn=<DivBackward0>)
# epoch number 120 ,loss =  tensor(51.8839, grad_fn=<DivBackward0>)
# epoch number 121 ,loss =  tensor(51.8339, grad_fn=<DivBackward0>)
# epoch number 122 ,loss =  tensor(51.7099, grad_fn=<DivBackward0>)
# epoch number 123 ,loss =  tensor(51.6097, grad_fn=<DivBackward0>)
# epoch number 124 ,loss =  tensor(51.6066, grad_fn=<DivBackward0>)
# epoch number 125 ,loss =  tensor(51.5329, grad_fn=<DivBackward0>)
# epoch number 126 ,loss =  tensor(51.5315, grad_fn=<DivBackward0>)
# epoch number 127 ,loss =  tensor(51.6631, grad_fn=<DivBackward0>)
# epoch number 128 ,loss =  tensor(51.6436, grad_fn=<DivBackward0>)
# epoch number 129 ,loss =  tensor(51.7765, grad_fn=<DivBackward0>)
# epoch number 130 ,loss =  tensor(51.7624, grad_fn=<DivBackward0>)
# epoch number 131 ,loss =  tensor(51.5924, grad_fn=<DivBackward0>)
# epoch number 132 ,loss =  tensor(51.6979, grad_fn=<DivBackward0>)
# epoch number 133 ,loss =  tensor(51.8563, grad_fn=<DivBackward0>)
# epoch number 134 ,loss =  tensor(51.9211, grad_fn=<DivBackward0>)
# epoch number 135 ,loss =  tensor(51.8136, grad_fn=<DivBackward0>)
# epoch number 136 ,loss =  tensor(51.6735, grad_fn=<DivBackward0>)
# epoch number 137 ,loss =  tensor(51.7117, grad_fn=<DivBackward0>)
# epoch number 138 ,loss =  tensor(51.5717, grad_fn=<DivBackward0>)
# epoch number 139 ,loss =  tensor(51.7384, grad_fn=<DivBackward0>)
# epoch number 140 ,loss =  tensor(51.8761, grad_fn=<DivBackward0>)
# epoch number 141 ,loss =  tensor(51.9608, grad_fn=<DivBackward0>)
# epoch number 142 ,loss =  tensor(51.9829, grad_fn=<DivBackward0>)
# epoch number 143 ,loss =  tensor(51.9695, grad_fn=<DivBackward0>)
# epoch number 144 ,loss =  tensor(51.9598, grad_fn=<DivBackward0>)
# epoch number 145 ,loss =  tensor(51.9903, grad_fn=<DivBackward0>)
# epoch number 146 ,loss =  tensor(51.9485, grad_fn=<DivBackward0>)
# epoch number 147 ,loss =  tensor(51.7631, grad_fn=<DivBackward0>)
# epoch number 148 ,loss =  tensor(51.6724, grad_fn=<DivBackward0>)
# epoch number 149 ,loss =  tensor(51.9334, grad_fn=<DivBackward0>)
# epoch number 150 ,loss =  tensor(52.2126, grad_fn=<DivBackward0>)
# epoch number 151 ,loss =  tensor(51.9298, grad_fn=<DivBackward0>)
# epoch number 152 ,loss =  tensor(51.8032, grad_fn=<DivBackward0>)
# epoch number 153 ,loss =  tensor(51.8059, grad_fn=<DivBackward0>)
# epoch number 154 ,loss =  tensor(51.9744, grad_fn=<DivBackward0>)
# epoch number 155 ,loss =  tensor(52.1164, grad_fn=<DivBackward0>)
# epoch number 156 ,loss =  tensor(52.0875, grad_fn=<DivBackward0>)
# epoch number 157 ,loss =  tensor(51.8407, grad_fn=<DivBackward0>)
# epoch number 158 ,loss =  tensor(51.9111, grad_fn=<DivBackward0>)
# epoch number 159 ,loss =  tensor(51.9480, grad_fn=<DivBackward0>)
# epoch number 160 ,loss =  tensor(52.0058, grad_fn=<DivBackward0>)
# epoch number 161 ,loss =  tensor(51.8796, grad_fn=<DivBackward0>)
# epoch number 162 ,loss =  tensor(51.9204, grad_fn=<DivBackward0>)
# epoch number 163 ,loss =  tensor(51.9857, grad_fn=<DivBackward0>)
# epoch number 164 ,loss =  tensor(51.9907, grad_fn=<DivBackward0>)
# epoch number 165 ,loss =  tensor(51.9508, grad_fn=<DivBackward0>)
# epoch number 166 ,loss =  tensor(51.8430, grad_fn=<DivBackward0>)
# epoch number 167 ,loss =  tensor(51.8912, grad_fn=<DivBackward0>)
# epoch number 168 ,loss =  tensor(51.6822, grad_fn=<DivBackward0>)
# epoch number 169 ,loss =  tensor(51.6534, grad_fn=<DivBackward0>)
# epoch number 170 ,loss =  tensor(51.4858, grad_fn=<DivBackward0>)
# epoch number 171 ,loss =  tensor(51.5598, grad_fn=<DivBackward0>)
# epoch number 172 ,loss =  tensor(51.6639, grad_fn=<DivBackward0>)
# epoch number 173 ,loss =  tensor(51.6315, grad_fn=<DivBackward0>)
# epoch number 174 ,loss =  tensor(51.7631, grad_fn=<DivBackward0>)
# epoch number 175 ,loss =  tensor(51.7444, grad_fn=<DivBackward0>)
# epoch number 176 ,loss =  tensor(51.7166, grad_fn=<DivBackward0>)
# epoch number 177 ,loss =  tensor(51.6472, grad_fn=<DivBackward0>)
# epoch number 178 ,loss =  tensor(51.5961, grad_fn=<DivBackward0>)
# epoch number 179 ,loss =  tensor(51.5612, grad_fn=<DivBackward0>)
# epoch number 180 ,loss =  tensor(51.5294, grad_fn=<DivBackward0>)
# epoch number 181 ,loss =  tensor(51.5045, grad_fn=<DivBackward0>)
# epoch number 182 ,loss =  tensor(51.5507, grad_fn=<DivBackward0>)
# epoch number 183 ,loss =  tensor(51.6352, grad_fn=<DivBackward0>)
# epoch number 184 ,loss =  tensor(51.6701, grad_fn=<DivBackward0>)
# epoch number 185 ,loss =  tensor(51.5895, grad_fn=<DivBackward0>)
# epoch number 186 ,loss =  tensor(51.4476, grad_fn=<DivBackward0>)
# epoch number 187 ,loss =  tensor(51.4252, grad_fn=<DivBackward0>)
# epoch number 188 ,loss =  tensor(51.4137, grad_fn=<DivBackward0>)
# epoch number 189 ,loss =  tensor(51.4581, grad_fn=<DivBackward0>)
# epoch number 190 ,loss =  tensor(51.3724, grad_fn=<DivBackward0>)
# epoch number 191 ,loss =  tensor(51.4233, grad_fn=<DivBackward0>)
# epoch number 192 ,loss =  tensor(51.2956, grad_fn=<DivBackward0>)
# epoch number 193 ,loss =  tensor(51.2729, grad_fn=<DivBackward0>)
# epoch number 194 ,loss =  tensor(51.3789, grad_fn=<DivBackward0>)
# epoch number 195 ,loss =  tensor(51.4196, grad_fn=<DivBackward0>)
# epoch number 196 ,loss =  tensor(51.3662, grad_fn=<DivBackward0>)
# epoch number 197 ,loss =  tensor(51.3364, grad_fn=<DivBackward0>)
# epoch number 198 ,loss =  tensor(51.2638, grad_fn=<DivBackward0>)
# epoch number 199 ,loss =  tensor(51.2759, grad_fn=<DivBackward0>)
# epoch number 200 ,loss =  tensor(51.2341, grad_fn=<DivBackward0>)
# epoch number 201 ,loss =  tensor(51.2775, grad_fn=<DivBackward0>)
# epoch number 202 ,loss =  tensor(51.3083, grad_fn=<DivBackward0>)
# epoch number 203 ,loss =  tensor(51.2513, grad_fn=<DivBackward0>)
# epoch number 204 ,loss =  tensor(51.2366, grad_fn=<DivBackward0>)
# epoch number 205 ,loss =  tensor(51.2536, grad_fn=<DivBackward0>)
# epoch number 206 ,loss =  tensor(51.2714, grad_fn=<DivBackward0>)
# epoch number 207 ,loss =  tensor(51.2585, grad_fn=<DivBackward0>)
# epoch number 208 ,loss =  tensor(51.2759, grad_fn=<DivBackward0>)
# epoch number 209 ,loss =  tensor(51.2838, grad_fn=<DivBackward0>)
# epoch number 210 ,loss =  tensor(51.3060, grad_fn=<DivBackward0>)
# epoch number 211 ,loss =  tensor(51.2337, grad_fn=<DivBackward0>)
# epoch number 212 ,loss =  tensor(51.2797, grad_fn=<DivBackward0>)
# epoch number 213 ,loss =  tensor(51.2828, grad_fn=<DivBackward0>)
# epoch number 214 ,loss =  tensor(51.2538, grad_fn=<DivBackward0>)
# epoch number 215 ,loss =  tensor(51.2313, grad_fn=<DivBackward0>)
# epoch number 216 ,loss =  tensor(51.2258, grad_fn=<DivBackward0>)
# epoch number 217 ,loss =  tensor(51.1764, grad_fn=<DivBackward0>)
# epoch number 218 ,loss =  tensor(51.2013, grad_fn=<DivBackward0>)
# epoch number 219 ,loss =  tensor(51.2798, grad_fn=<DivBackward0>)
# epoch number 220 ,loss =  tensor(51.2845, grad_fn=<DivBackward0>)
# epoch number 221 ,loss =  tensor(51.2412, grad_fn=<DivBackward0>)
# epoch number 222 ,loss =  tensor(51.2224, grad_fn=<DivBackward0>)
# epoch number 223 ,loss =  tensor(51.2203, grad_fn=<DivBackward0>)
# epoch number 224 ,loss =  tensor(51.1547, grad_fn=<DivBackward0>)
# epoch number 225 ,loss =  tensor(51.1242, grad_fn=<DivBackward0>)
# epoch number 226 ,loss =  tensor(51.1884, grad_fn=<DivBackward0>)
# epoch number 227 ,loss =  tensor(51.0735, grad_fn=<DivBackward0>)
# epoch number 228 ,loss =  tensor(51.1493, grad_fn=<DivBackward0>)
# epoch number 229 ,loss =  tensor(51.1663, grad_fn=<DivBackward0>)
# epoch number 230 ,loss =  tensor(51.1551, grad_fn=<DivBackward0>)
# epoch number 231 ,loss =  tensor(51.1556, grad_fn=<DivBackward0>)
# epoch number 232 ,loss =  tensor(51.1627, grad_fn=<DivBackward0>)
# epoch number 233 ,loss =  tensor(51.1264, grad_fn=<DivBackward0>)
# epoch number 234 ,loss =  tensor(51.1698, grad_fn=<DivBackward0>)
# epoch number 235 ,loss =  tensor(51.2399, grad_fn=<DivBackward0>)
# epoch number 236 ,loss =  tensor(51.2497, grad_fn=<DivBackward0>)
# epoch number 237 ,loss =  tensor(51.3258, grad_fn=<DivBackward0>)
# epoch number 238 ,loss =  tensor(51.2536, grad_fn=<DivBackward0>)
# epoch number 239 ,loss =  tensor(51.2646, grad_fn=<DivBackward0>)
# epoch number 240 ,loss =  tensor(51.2985, grad_fn=<DivBackward0>)
# epoch number 241 ,loss =  tensor(51.4082, grad_fn=<DivBackward0>)
# epoch number 242 ,loss =  tensor(51.4465, grad_fn=<DivBackward0>)
# epoch number 243 ,loss =  tensor(51.4567, grad_fn=<DivBackward0>)
# epoch number 244 ,loss =  tensor(51.4291, grad_fn=<DivBackward0>)
# epoch number 245 ,loss =  tensor(51.5068, grad_fn=<DivBackward0>)
# epoch number 246 ,loss =  tensor(51.4762, grad_fn=<DivBackward0>)
# epoch number 247 ,loss =  tensor(51.4432, grad_fn=<DivBackward0>)
# epoch number 248 ,loss =  tensor(51.4931, grad_fn=<DivBackward0>)
# epoch number 249 ,loss =  tensor(51.4413, grad_fn=<DivBackward0>)
# epoch number 250 ,loss =  tensor(51.3940, grad_fn=<DivBackward0>)
# epoch number 251 ,loss =  tensor(51.3781, grad_fn=<DivBackward0>)
# epoch number 252 ,loss =  tensor(51.4145, grad_fn=<DivBackward0>)
# epoch number 253 ,loss =  tensor(51.3989, grad_fn=<DivBackward0>)
# epoch number 254 ,loss =  tensor(51.4877, grad_fn=<DivBackward0>)
# epoch number 255 ,loss =  tensor(51.4771, grad_fn=<DivBackward0>)
# epoch number 256 ,loss =  tensor(51.8606, grad_fn=<DivBackward0>)
# epoch number 257 ,loss =  tensor(52.1240, grad_fn=<DivBackward0>)
# epoch number 258 ,loss =  tensor(51.9257, grad_fn=<DivBackward0>)
# epoch number 259 ,loss =  tensor(51.7683, grad_fn=<DivBackward0>)
# epoch number 260 ,loss =  tensor(51.6086, grad_fn=<DivBackward0>)
# epoch number 261 ,loss =  tensor(51.6059, grad_fn=<DivBackward0>)
# epoch number 262 ,loss =  tensor(51.4679, grad_fn=<DivBackward0>)
# epoch number 263 ,loss =  tensor(51.7541, grad_fn=<DivBackward0>)
# epoch number 264 ,loss =  tensor(51.7678, grad_fn=<DivBackward0>)
# epoch number 265 ,loss =  tensor(51.6020, grad_fn=<DivBackward0>)
# epoch number 266 ,loss =  tensor(51.5367, grad_fn=<DivBackward0>)
# epoch number 267 ,loss =  tensor(51.5156, grad_fn=<DivBackward0>)
# epoch number 268 ,loss =  tensor(51.5921, grad_fn=<DivBackward0>)
# epoch number 269 ,loss =  tensor(51.4907, grad_fn=<DivBackward0>)
# epoch number 270 ,loss =  tensor(51.6182, grad_fn=<DivBackward0>)
# epoch number 271 ,loss =  tensor(51.6809, grad_fn=<DivBackward0>)
# epoch number 272 ,loss =  tensor(51.7801, grad_fn=<DivBackward0>)
# epoch number 273 ,loss =  tensor(51.6733, grad_fn=<DivBackward0>)
# epoch number 274 ,loss =  tensor(51.4723, grad_fn=<DivBackward0>)
# epoch number 275 ,loss =  tensor(51.4098, grad_fn=<DivBackward0>)
# epoch number 276 ,loss =  tensor(51.4777, grad_fn=<DivBackward0>)
# epoch number 277 ,loss =  tensor(51.4669, grad_fn=<DivBackward0>)
# epoch number 278 ,loss =  tensor(51.4305, grad_fn=<DivBackward0>)
# epoch number 279 ,loss =  tensor(51.3044, grad_fn=<DivBackward0>)
# epoch number 280 ,loss =  tensor(51.2809, grad_fn=<DivBackward0>)
# epoch number 281 ,loss =  tensor(51.3735, grad_fn=<DivBackward0>)
# epoch number 282 ,loss =  tensor(51.4125, grad_fn=<DivBackward0>)
# epoch number 283 ,loss =  tensor(51.5626, grad_fn=<DivBackward0>)
# epoch number 284 ,loss =  tensor(51.4792, grad_fn=<DivBackward0>)
# epoch number 285 ,loss =  tensor(51.3569, grad_fn=<DivBackward0>)
# epoch number 286 ,loss =  tensor(51.4187, grad_fn=<DivBackward0>)
# epoch number 287 ,loss =  tensor(51.4114, grad_fn=<DivBackward0>)
# epoch number 288 ,loss =  tensor(51.4802, grad_fn=<DivBackward0>)
# epoch number 289 ,loss =  tensor(51.5516, grad_fn=<DivBackward0>)
# epoch number 290 ,loss =  tensor(51.4300, grad_fn=<DivBackward0>)
# epoch number 291 ,loss =  tensor(51.3173, grad_fn=<DivBackward0>)
# epoch number 292 ,loss =  tensor(51.3853, grad_fn=<DivBackward0>)
# epoch number 293 ,loss =  tensor(51.3902, grad_fn=<DivBackward0>)
# epoch number 294 ,loss =  tensor(51.3806, grad_fn=<DivBackward0>)
# epoch number 295 ,loss =  tensor(51.3700, grad_fn=<DivBackward0>)
# epoch number 296 ,loss =  tensor(51.3325, grad_fn=<DivBackward0>)
# epoch number 297 ,loss =  tensor(51.3531, grad_fn=<DivBackward0>)
# epoch number 298 ,loss =  tensor(51.3324, grad_fn=<DivBackward0>)
# epoch number 299 ,loss =  tensor(51.3362, grad_fn=<DivBackward0>)
# epoch number 300 ,loss =  tensor(51.3502, grad_fn=<DivBackward0>)
# epoch number 301 ,loss =  tensor(51.4546, grad_fn=<DivBackward0>)
# epoch number 302 ,loss =  tensor(51.5578, grad_fn=<DivBackward0>)
# epoch number 303 ,loss =  tensor(51.4227, grad_fn=<DivBackward0>)
# epoch number 304 ,loss =  tensor(51.6968, grad_fn=<DivBackward0>)
# epoch number 305 ,loss =  tensor(51.8979, grad_fn=<DivBackward0>)
# epoch number 306 ,loss =  tensor(51.6047, grad_fn=<DivBackward0>)
# epoch number 307 ,loss =  tensor(51.3602, grad_fn=<DivBackward0>)
# epoch number 308 ,loss =  tensor(51.5789, grad_fn=<DivBackward0>)
# epoch number 309 ,loss =  tensor(51.6118, grad_fn=<DivBackward0>)
# epoch number 310 ,loss =  tensor(51.7485, grad_fn=<DivBackward0>)
# epoch number 311 ,loss =  tensor(51.8467, grad_fn=<DivBackward0>)
# epoch number 312 ,loss =  tensor(51.8992, grad_fn=<DivBackward0>)
# epoch number 313 ,loss =  tensor(51.7730, grad_fn=<DivBackward0>)
# epoch number 314 ,loss =  tensor(51.6335, grad_fn=<DivBackward0>)
# epoch number 315 ,loss =  tensor(51.4395, grad_fn=<DivBackward0>)
# epoch number 316 ,loss =  tensor(51.4151, grad_fn=<DivBackward0>)
# epoch number 317 ,loss =  tensor(51.4697, grad_fn=<DivBackward0>)
# epoch number 318 ,loss =  tensor(51.6601, grad_fn=<DivBackward0>)
# epoch number 319 ,loss =  tensor(51.6656, grad_fn=<DivBackward0>)
# epoch number 320 ,loss =  tensor(51.5786, grad_fn=<DivBackward0>)
# epoch number 321 ,loss =  tensor(51.5102, grad_fn=<DivBackward0>)
# epoch number 322 ,loss =  tensor(52.0762, grad_fn=<DivBackward0>)
# epoch number 323 ,loss =  tensor(52.5719, grad_fn=<DivBackward0>)
# epoch number 324 ,loss =  tensor(52.5366, grad_fn=<DivBackward0>)
# epoch number 325 ,loss =  tensor(52.0782, grad_fn=<DivBackward0>)
# epoch number 326 ,loss =  tensor(51.6538, grad_fn=<DivBackward0>)
# epoch number 327 ,loss =  tensor(51.5127, grad_fn=<DivBackward0>)
# epoch number 328 ,loss =  tensor(52.1343, grad_fn=<DivBackward0>)
# epoch number 329 ,loss =  tensor(52.7575, grad_fn=<DivBackward0>)
# epoch number 330 ,loss =  tensor(53.0072, grad_fn=<DivBackward0>)
# epoch number 331 ,loss =  tensor(52.4148, grad_fn=<DivBackward0>)
# epoch number 332 ,loss =  tensor(52.1460, grad_fn=<DivBackward0>)
# epoch number 333 ,loss =  tensor(51.9632, grad_fn=<DivBackward0>)
# epoch number 334 ,loss =  tensor(52.1473, grad_fn=<DivBackward0>)
# epoch number 335 ,loss =  tensor(52.1820, grad_fn=<DivBackward0>)
# epoch number 336 ,loss =  tensor(52.3420, grad_fn=<DivBackward0>)
# epoch number 337 ,loss =  tensor(52.1865, grad_fn=<DivBackward0>)
# epoch number 338 ,loss =  tensor(52.0396, grad_fn=<DivBackward0>)
# epoch number 339 ,loss =  tensor(51.8537, grad_fn=<DivBackward0>)
# epoch number 340 ,loss =  tensor(51.9284, grad_fn=<DivBackward0>)
# epoch number 341 ,loss =  tensor(52.0003, grad_fn=<DivBackward0>)
# epoch number 342 ,loss =  tensor(51.9519, grad_fn=<DivBackward0>)
# epoch number 343 ,loss =  tensor(51.9518, grad_fn=<DivBackward0>)
# epoch number 344 ,loss =  tensor(51.7207, grad_fn=<DivBackward0>)
# epoch number 345 ,loss =  tensor(51.6645, grad_fn=<DivBackward0>)
# epoch number 346 ,loss =  tensor(51.7323, grad_fn=<DivBackward0>)
# epoch number 347 ,loss =  tensor(51.8067, grad_fn=<DivBackward0>)
# epoch number 348 ,loss =  tensor(51.6031, grad_fn=<DivBackward0>)
# epoch number 349 ,loss =  tensor(51.4412, grad_fn=<DivBackward0>)
# epoch number 350 ,loss =  tensor(51.5635, grad_fn=<DivBackward0>)
# epoch number 351 ,loss =  tensor(51.6373, grad_fn=<DivBackward0>)
# epoch number 352 ,loss =  tensor(51.8072, grad_fn=<DivBackward0>)
# epoch number 353 ,loss =  tensor(51.7978, grad_fn=<DivBackward0>)
# epoch number 354 ,loss =  tensor(51.7011, grad_fn=<DivBackward0>)
# epoch number 355 ,loss =  tensor(51.6294, grad_fn=<DivBackward0>)
# epoch number 356 ,loss =  tensor(51.4612, grad_fn=<DivBackward0>)
# epoch number 357 ,loss =  tensor(51.7302, grad_fn=<DivBackward0>)
# epoch number 358 ,loss =  tensor(51.7342, grad_fn=<DivBackward0>)
# epoch number 359 ,loss =  tensor(51.8627, grad_fn=<DivBackward0>)
# epoch number 360 ,loss =  tensor(51.7735, grad_fn=<DivBackward0>)
# epoch number 361 ,loss =  tensor(51.7419, grad_fn=<DivBackward0>)
# epoch number 362 ,loss =  tensor(51.7020, grad_fn=<DivBackward0>)
# epoch number 363 ,loss =  tensor(51.6513, grad_fn=<DivBackward0>)
# epoch number 364 ,loss =  tensor(51.6478, grad_fn=<DivBackward0>)
# epoch number 365 ,loss =  tensor(51.6375, grad_fn=<DivBackward0>)
# epoch number 366 ,loss =  tensor(51.7694, grad_fn=<DivBackward0>)
# epoch number 367 ,loss =  tensor(51.9324, grad_fn=<DivBackward0>)
# epoch number 368 ,loss =  tensor(51.8342, grad_fn=<DivBackward0>)
# epoch number 369 ,loss =  tensor(51.7984, grad_fn=<DivBackward0>)
# epoch number 370 ,loss =  tensor(51.7496, grad_fn=<DivBackward0>)
# epoch number 371 ,loss =  tensor(51.5990, grad_fn=<DivBackward0>)
# epoch number 372 ,loss =  tensor(51.6450, grad_fn=<DivBackward0>)
# epoch number 373 ,loss =  tensor(51.7017, grad_fn=<DivBackward0>)
# epoch number 374 ,loss =  tensor(51.5758, grad_fn=<DivBackward0>)
# epoch number 375 ,loss =  tensor(51.5324, grad_fn=<DivBackward0>)
# epoch number 376 ,loss =  tensor(51.3324, grad_fn=<DivBackward0>)
# epoch number 377 ,loss =  tensor(51.3390, grad_fn=<DivBackward0>)
# epoch number 378 ,loss =  tensor(51.6462, grad_fn=<DivBackward0>)
# epoch number 379 ,loss =  tensor(52.1097, grad_fn=<DivBackward0>)
# epoch number 380 ,loss =  tensor(52.2037, grad_fn=<DivBackward0>)
# epoch number 381 ,loss =  tensor(52.1400, grad_fn=<DivBackward0>)
# epoch number 382 ,loss =  tensor(52.0870, grad_fn=<DivBackward0>)
# epoch number 383 ,loss =  tensor(51.9629, grad_fn=<DivBackward0>)
# epoch number 384 ,loss =  tensor(51.7989, grad_fn=<DivBackward0>)
# epoch number 385 ,loss =  tensor(51.8451, grad_fn=<DivBackward0>)
# epoch number 386 ,loss =  tensor(52.4846, grad_fn=<DivBackward0>)
# epoch number 387 ,loss =  tensor(52.6557, grad_fn=<DivBackward0>)
# epoch number 388 ,loss =  tensor(52.4389, grad_fn=<DivBackward0>)
# epoch number 389 ,loss =  tensor(52.3491, grad_fn=<DivBackward0>)
# epoch number 390 ,loss =  tensor(52.3281, grad_fn=<DivBackward0>)
# epoch number 391 ,loss =  tensor(52.2674, grad_fn=<DivBackward0>)
# epoch number 392 ,loss =  tensor(52.5518, grad_fn=<DivBackward0>)
# epoch number 393 ,loss =  tensor(52.3584, grad_fn=<DivBackward0>)
# epoch number 394 ,loss =  tensor(52.8186, grad_fn=<DivBackward0>)
# epoch number 395 ,loss =  tensor(53.6781, grad_fn=<DivBackward0>)
# epoch number 396 ,loss =  tensor(52.9544, grad_fn=<DivBackward0>)
# epoch number 397 ,loss =  tensor(52.1145, grad_fn=<DivBackward0>)
# epoch number 398 ,loss =  tensor(51.9741, grad_fn=<DivBackward0>)
# epoch number 399 ,loss =  tensor(52.1993, grad_fn=<DivBackward0>)
# epoch number 400 ,loss =  tensor(52.5204, grad_fn=<DivBackward0>)
# epoch number 401 ,loss =  tensor(52.4463, grad_fn=<DivBackward0>)
# epoch number 402 ,loss =  tensor(52.5314, grad_fn=<DivBackward0>)
# epoch number 403 ,loss =  tensor(52.5966, grad_fn=<DivBackward0>)
# epoch number 404 ,loss =  tensor(52.5489, grad_fn=<DivBackward0>)
# epoch number 405 ,loss =  tensor(52.5843, grad_fn=<DivBackward0>)
# epoch number 406 ,loss =  tensor(52.4838, grad_fn=<DivBackward0>)
# epoch number 407 ,loss =  tensor(52.3897, grad_fn=<DivBackward0>)
# epoch number 408 ,loss =  tensor(52.3921, grad_fn=<DivBackward0>)
# epoch number 409 ,loss =  tensor(52.4164, grad_fn=<DivBackward0>)
# epoch number 410 ,loss =  tensor(52.3820, grad_fn=<DivBackward0>)
# epoch number 411 ,loss =  tensor(52.3793, grad_fn=<DivBackward0>)
# epoch number 412 ,loss =  tensor(52.3742, grad_fn=<DivBackward0>)
# epoch number 413 ,loss =  tensor(52.4368, grad_fn=<DivBackward0>)
# epoch number 414 ,loss =  tensor(52.7045, grad_fn=<DivBackward0>)
# epoch number 415 ,loss =  tensor(52.9831, grad_fn=<DivBackward0>)
# epoch number 416 ,loss =  tensor(52.9919, grad_fn=<DivBackward0>)
# epoch number 417 ,loss =  tensor(52.9518, grad_fn=<DivBackward0>)
# epoch number 418 ,loss =  tensor(52.9033, grad_fn=<DivBackward0>)
# epoch number 419 ,loss =  tensor(52.7599, grad_fn=<DivBackward0>)
# epoch number 420 ,loss =  tensor(52.4044, grad_fn=<DivBackward0>)
# epoch number 421 ,loss =  tensor(52.3267, grad_fn=<DivBackward0>)
# epoch number 422 ,loss =  tensor(52.3904, grad_fn=<DivBackward0>)
# epoch number 423 ,loss =  tensor(53.0924, grad_fn=<DivBackward0>)
# epoch number 424 ,loss =  tensor(52.9690, grad_fn=<DivBackward0>)
# epoch number 425 ,loss =  tensor(52.3616, grad_fn=<DivBackward0>)
# epoch number 426 ,loss =  tensor(52.0213, grad_fn=<DivBackward0>)
# epoch number 427 ,loss =  tensor(52.3619, grad_fn=<DivBackward0>)
# epoch number 428 ,loss =  tensor(52.9059, grad_fn=<DivBackward0>)
# epoch number 429 ,loss =  tensor(53.0263, grad_fn=<DivBackward0>)
# epoch number 430 ,loss =  tensor(52.7186, grad_fn=<DivBackward0>)
# epoch number 431 ,loss =  tensor(52.3423, grad_fn=<DivBackward0>)
# epoch number 432 ,loss =  tensor(51.9982, grad_fn=<DivBackward0>)
# epoch number 433 ,loss =  tensor(51.8657, grad_fn=<DivBackward0>)
# epoch number 434 ,loss =  tensor(51.9533, grad_fn=<DivBackward0>)
# epoch number 435 ,loss =  tensor(52.4068, grad_fn=<DivBackward0>)
# epoch number 436 ,loss =  tensor(52.5153, grad_fn=<DivBackward0>)
# epoch number 437 ,loss =  tensor(52.1739, grad_fn=<DivBackward0>)
# epoch number 438 ,loss =  tensor(51.8738, grad_fn=<DivBackward0>)
# epoch number 439 ,loss =  tensor(51.7065, grad_fn=<DivBackward0>)
# epoch number 440 ,loss =  tensor(51.7971, grad_fn=<DivBackward0>)
# epoch number 441 ,loss =  tensor(51.9646, grad_fn=<DivBackward0>)
# epoch number 442 ,loss =  tensor(52.1242, grad_fn=<DivBackward0>)
# epoch number 443 ,loss =  tensor(52.2846, grad_fn=<DivBackward0>)
# epoch number 444 ,loss =  tensor(52.3794, grad_fn=<DivBackward0>)
# epoch number 445 ,loss =  tensor(52.3183, grad_fn=<DivBackward0>)
# epoch number 446 ,loss =  tensor(52.0608, grad_fn=<DivBackward0>)
# epoch number 447 ,loss =  tensor(51.9447, grad_fn=<DivBackward0>)
# epoch number 448 ,loss =  tensor(51.6903, grad_fn=<DivBackward0>)
# epoch number 449 ,loss =  tensor(51.7296, grad_fn=<DivBackward0>)
# epoch number 450 ,loss =  tensor(51.8556, grad_fn=<DivBackward0>)
# epoch number 451 ,loss =  tensor(51.8405, grad_fn=<DivBackward0>)
# epoch number 452 ,loss =  tensor(51.7753, grad_fn=<DivBackward0>)
# epoch number 453 ,loss =  tensor(51.6862, grad_fn=<DivBackward0>)
# epoch number 454 ,loss =  tensor(51.7645, grad_fn=<DivBackward0>)
# epoch number 455 ,loss =  tensor(51.7843, grad_fn=<DivBackward0>)
# epoch number 456 ,loss =  tensor(51.6872, grad_fn=<DivBackward0>)
# epoch number 457 ,loss =  tensor(51.7670, grad_fn=<DivBackward0>)
# epoch number 458 ,loss =  tensor(51.6800, grad_fn=<DivBackward0>)
# epoch number 459 ,loss =  tensor(51.7255, grad_fn=<DivBackward0>)
# epoch number 460 ,loss =  tensor(51.6483, grad_fn=<DivBackward0>)
# epoch number 461 ,loss =  tensor(51.5982, grad_fn=<DivBackward0>)
# epoch number 462 ,loss =  tensor(51.5418, grad_fn=<DivBackward0>)
# epoch number 463 ,loss =  tensor(51.5099, grad_fn=<DivBackward0>)
# epoch number 464 ,loss =  tensor(51.4880, grad_fn=<DivBackward0>)
# epoch number 465 ,loss =  tensor(51.4932, grad_fn=<DivBackward0>)
# epoch number 466 ,loss =  tensor(51.4712, grad_fn=<DivBackward0>)
# epoch number 467 ,loss =  tensor(51.4019, grad_fn=<DivBackward0>)
# epoch number 468 ,loss =  tensor(51.5537, grad_fn=<DivBackward0>)
# epoch number 469 ,loss =  tensor(51.6904, grad_fn=<DivBackward0>)
# epoch number 470 ,loss =  tensor(51.9862, grad_fn=<DivBackward0>)
# epoch number 471 ,loss =  tensor(52.2408, grad_fn=<DivBackward0>)
# epoch number 472 ,loss =  tensor(52.6405, grad_fn=<DivBackward0>)
# epoch number 473 ,loss =  tensor(53.1011, grad_fn=<DivBackward0>)
# epoch number 474 ,loss =  tensor(53.2964, grad_fn=<DivBackward0>)
# epoch number 475 ,loss =  tensor(53.6489, grad_fn=<DivBackward0>)
# epoch number 476 ,loss =  tensor(53.2779, grad_fn=<DivBackward0>)
# epoch number 477 ,loss =  tensor(52.9329, grad_fn=<DivBackward0>)
# epoch number 478 ,loss =  tensor(53.1486, grad_fn=<DivBackward0>)
# epoch number 479 ,loss =  tensor(53.4637, grad_fn=<DivBackward0>)
# epoch number 480 ,loss =  tensor(56.6613, grad_fn=<DivBackward0>)
# epoch number 481 ,loss =  tensor(54.0500, grad_fn=<DivBackward0>)
# epoch number 482 ,loss =  tensor(53.1421, grad_fn=<DivBackward0>)
# epoch number 483 ,loss =  tensor(53.0064, grad_fn=<DivBackward0>)
# epoch number 484 ,loss =  tensor(53.1692, grad_fn=<DivBackward0>)
# epoch number 485 ,loss =  tensor(53.6042, grad_fn=<DivBackward0>)
# epoch number 486 ,loss =  tensor(53.9445, grad_fn=<DivBackward0>)
# epoch number 487 ,loss =  tensor(54.1376, grad_fn=<DivBackward0>)
# epoch number 488 ,loss =  tensor(53.7899, grad_fn=<DivBackward0>)
# epoch number 489 ,loss =  tensor(53.0858, grad_fn=<DivBackward0>)
# epoch number 490 ,loss =  tensor(52.9001, grad_fn=<DivBackward0>)
# epoch number 491 ,loss =  tensor(53.3494, grad_fn=<DivBackward0>)
# epoch number 492 ,loss =  tensor(53.3641, grad_fn=<DivBackward0>)
# epoch number 493 ,loss =  tensor(53.5062, grad_fn=<DivBackward0>)
# epoch number 494 ,loss =  tensor(53.3369, grad_fn=<DivBackward0>)
# epoch number 495 ,loss =  tensor(52.8562, grad_fn=<DivBackward0>)
# epoch number 496 ,loss =  tensor(52.5525, grad_fn=<DivBackward0>)
# epoch number 497 ,loss =  tensor(52.4520, grad_fn=<DivBackward0>)
# epoch number 498 ,loss =  tensor(52.5548, grad_fn=<DivBackward0>)
# epoch number 499 ,loss =  tensor(52.9028, grad_fn=<DivBackward0>)

# %%
# Benchmark Network
    
def configure_benchmark():
    
    lsd = 3
    ph_dim = 1 #16
    
    V = MakePSD(ICNN([lsd, ph_dim, ph_dim, 1], activation=ReHU(0.01)), lsd, eps = 0.5, d = 1.0, w1 = 0.0, w2 = 1.0)

    
    global potentialFunction2
    potentialFunction2 = V

# %%
configure_benchmark()
model2 = Dynamics(potentialFunction2, J, Kd, RDes, nSim, dt)

# %%
R0_test = so3_exp_map(torch.randn(1,3, dtype = torch.float32, requires_grad = True))[0]
omega0_test = 5*torch.randn(3,1, dtype = torch.float32, requires_grad = True)

R_NN, omega_NN = model(R0_test, omega0_test)
R_benchmark, omega_benchmark = model2(R0_test, omega0_test)


Psi_NN = torch.zeros(nSim, dtype = torch.float32)
Psi_benchmark = torch.zeros(nSim, dtype = torch.float32)

errorKE_NN = torch.zeros(nSim, dtype = torch.float32)
errorKE_benchmark = torch.zeros(nSim, dtype = torch.float32)

for i in range(len(R_NN)):
    Psi_NN[i] = potentialFunction2(0.5*(RDes.permute(1,0)@R_NN['e'+str(i)]+R_NN['e'+str(i)].permute(1,0)))

    Psi_benchmark[i] = potentialFunction2(0.5*(RDes.permute(1,0)@R_benchmark['e'+str(i)]+R_benchmark['e'+str(i)].permute(1,0)))
    
    errorKE_NN[i] = torch.norm(omega_NN['e'+str(i)])
    errorKE_benchmark[i] = torch.norm(omega_benchmark['e'+str(i)])
    
plt.plot(Psi_NN.detach().numpy(), 'b-', label='learnt')
plt.plot(Psi_benchmark.detach().numpy(), 'r-', label='Frobenius')
plt.grid()
plt.legend()
plt.show()

plt.plot(errorKE_NN.detach().numpy(), 'b-', label='learnt')
plt.plot(errorKE_benchmark.detach().numpy(), 'r-', label='Frobenius')
plt.grid()
plt.legend()
plt.show()

# %%
# Test with large initial errors
Rpioff = so3_exp_map(torch.pi*torch.tensor([[1.0, 0.0, 0.0]], dtype = torch.float32, requires_grad = False))[0]
R0_test = so3_exp_map(0.001*torch.randn(1,3, dtype = torch.float32, requires_grad = True))[0]@Rpioff
omega0_test = 0*torch.randn(3,1, dtype = torch.float32, requires_grad = True)

R_NN, omega_NN = model(R0_test, omega0_test)
R_benchmark, omega_benchmark = model2(R0_test, omega0_test)


Psi_NN = torch.zeros(nSim, dtype = torch.float32)
Psi_benchmark = torch.zeros(nSim, dtype = torch.float32)

errorKE_NN = torch.zeros(nSim, dtype = torch.float32)
errorKE_benchmark = torch.zeros(nSim, dtype = torch.float32)

for i in range(len(R_NN)):
    Psi_NN[i] = potentialFunction2(0.5*(RDes.permute(1,0)@R_NN['e'+str(i)]+R_NN['e'+str(i)].permute(1,0)))

    Psi_benchmark[i] = potentialFunction2(0.5*(RDes.permute(1,0)@R_benchmark['e'+str(i)]+R_benchmark['e'+str(i)].permute(1,0)))
    
    errorKE_NN[i] = torch.norm(omega_NN['e'+str(i)])
    errorKE_benchmark[i] = torch.norm(omega_benchmark['e'+str(i)])
    
plt.plot(Psi_NN.detach().numpy(), 'b-', label='learnt')
plt.plot(Psi_benchmark.detach().numpy(), 'r-', label='Frobenius')
plt.grid()
plt.legend()
plt.show()

plt.plot(errorKE_NN.detach().numpy(), 'b-', label='learnt')
plt.plot(errorKE_benchmark.detach().numpy(), 'r-', label='Frobenius')
plt.grid()
plt.legend()
plt.show()

# %%
class MakePSD2(nn.Module):
    def __init__(self, f, n, eps=0.01, d=1.0, w1 = 1.0, w2 = 1.0):
        super().__init__()
        self.f = f
        self.zero = nn.Parameter(f(torch.eye(3, dtype = torch.float32)), requires_grad=False)
        self.eps = eps
        self.d = d
        self.rehu = ReHU(self.d)
        self.w1 = w1
        self.w2 = w2

    def forward(self, x):
        smoothed_output = self.rehu(self.f(x) - self.zero)
        quadratic_under = torch.norm(self.eps*so3_log_map(x.unsqueeze(0))[0])**2 #self.eps*(x**2).sum(1,keepdim=True)
        
        '''
        w1 and w2 are weights on the output and the quadratic term.
        w1 = 0 makes the output the Frobenius norm eps*||log[Rd'*R]||_F^2
        '''
    
        return self.w1*smoothed_output + self.w2*quadratic_under
    
    
class Dynamics2(nn.Module):
    
    def __init__(self, differentiable_model, J =  torch.eye(3, dtype = torch.float32), Kd = torch.eye(3, dtype = torch.float32), Rd = torch.eye(3, dtype = torch.float32), nSim = 100, dt = 0.1):
        super().__init__()

        self.differentiable_model = differentiable_model # Potential Function
        self.J = J # Inertia Tensor
        self.Kd = Kd # Damping matrix
        self.Rd = Rd # Desired final orientation
        self.nSim = nSim #number of euler forward steps
        self.dt = dt # sampling time
        
    def proportionalControl(self, R):
        
        '''
        R is the current rotaton matrix state
        Rd is the desired rotation matrix 
        '''
        
        '''
        create a lie algebra element eta and move along eta by eps
        take limit eps --> 0
        differentiate wrt eta to obtain the gradient (should be the same for any eta) 
        
        '''

        
        # epsilon for obtaining the limit for a small variation
        eps = torch.tensor(0.0, dtype = torch.float32, requires_grad = True)
        
        # direction (lie algebra element) along which the variation is taken
        #eta = torch.randn(1, 3, dtype=torch.float32, requires_grad = True)
        
        eta = torch.tensor([[1.0, 1.0, 1.0]], dtype = torch.float32, requires_grad = True)
        
        # geometrically consistent variation
        delta_R = so3_exp_map(eta*eps)[0]
        
        # y+dy 
        y = self.differentiable_model(self.Rd.permute(1,0)@R@delta_R) # traditional forward pass
        
        # lt eps -> 0 ((y+dy)(eps) - y)/ eps
        dydeps = autograd.grad(y, eps , create_graph = True)[0]
        
        # grad_eta (dy.eta) = dy
        d1Phi = autograd.grad(dydeps, eta, create_graph = True)[0]

        return -d1Phi.permute(1,0)
    
    def derivativeControl(self, R, omega):
        
        dControl = -self.Kd@omega
        
        return dControl
    
    def dynamicalModel(self, R, omega, T):

        # Angular Velocity at next step
        omegaPlus = omega + torch.linalg.inv(self.J)@(torch.linalg.cross(self.J@omega,omega,dim = 0) + T) * self.dt
        
        # rotation matrix at next step
        RPlus = R@so3_exp_map(omega.permute(1,0)*self.dt)[0]
        
        return RPlus,omegaPlus
    
    def forward(self, R0, omega0):
        
        '''
        Forward function integrates the dynamics forward using dynamicalModel function 
        and obtains the trajectory for nSim time steps. 
        The trajectory consists of the rotation matrix R and the angular velocity vector omega
        at different time steps
        '''
        
        R,omega = {},{}
    
        R['e0'] = R0
        omega['e0'] = omega0
    
    
        for i in range(self.nSim-1):
        
            T = self.proportionalControl(R['e'+str(i)]) + self.derivativeControl(R['e'+str(i)], omega['e'+str(i)])
            
            R['e'+str(i+1)], omega['e'+str(i+1)] = self.dynamicalModel(R['e'+str(i)], omega['e'+str(i)], T)
            

        return R, omega

# %%
def configure_benchmark_log():
    
    lsd = 3
    ph_dim = 1 #16
    
    V = MakePSD2(ICNN([lsd, ph_dim, ph_dim, 1], activation=ReHU(0.01)), lsd, eps = 1, d = 1.0, w1 = 0.0, w2 = 1.0)

    
    global potentialFunction_log
    potentialFunction_log = V

# %%
configure_benchmark_log()
model_log = Dynamics2(potentialFunction_log, J, Kd, RDes, nSim, dt)

# %%
# Test with large initial errors
Rpioff = so3_exp_map(torch.pi*torch.tensor([[1.0, 0.0, 0.0]], dtype = torch.float32, requires_grad = False))[0]
R0_test = so3_exp_map(0.01*torch.randn(1,3, dtype = torch.float32, requires_grad = True))[0]@Rpioff
omega0_test = 0*torch.randn(3,1, dtype = torch.float32, requires_grad = True)

R_NN, omega_NN = model(R0_test, omega0_test)
R_benchmark_log, omega_benchmark_log = model_log(R0_test, omega0_test)
R_benchmark_F, omega_benchmark_F = model2(R0_test, omega0_test)

Psi_NN = torch.zeros(nSim, dtype = torch.float32)
Psi_benchmark_log = torch.zeros(nSim, dtype = torch.float32)
Psi_benchmark_F = torch.zeros(nSim, dtype = torch.float32)

errorKE_NN = torch.zeros(nSim, dtype = torch.float32)
errorKE_benchmark_log = torch.zeros(nSim, dtype = torch.float32)
errorKE_benchmark_F = torch.zeros(nSim, dtype = torch.float32)

for i in range(len(R_NN)):
    Psi_NN[i] = potentialFunction2(0.5*(RDes.permute(1,0)@R_NN['e'+str(i)]+R_NN['e'+str(i)].permute(1,0)))

    Psi_benchmark_log[i] = potentialFunction2(0.5*(RDes.permute(1,0)@R_benchmark_log['e'+str(i)]+R_benchmark_log['e'+str(i)].permute(1,0)))
    Psi_benchmark_F[i] = potentialFunction2(0.5*(RDes.permute(1,0)@R_benchmark_F['e'+str(i)]+R_benchmark_F['e'+str(i)].permute(1,0)))
    errorKE_NN[i] = torch.norm(omega_NN['e'+str(i)])
    errorKE_benchmark_log[i] = torch.norm(omega_benchmark_log['e'+str(i)])
    errorKE_benchmark_F[i] = torch.norm(omega_benchmark_F['e'+str(i)])
    
plt.plot(Psi_NN.detach().numpy(), 'b-', label='learnt')
plt.plot(Psi_benchmark_log.detach().numpy(), 'r-', label='log')
plt.plot(Psi_benchmark_F.detach().numpy(), 'g-', label='Frobenius')

plt.grid()
plt.legend()
plt.show()

plt.plot(errorKE_NN.detach().numpy(), 'b-', label='learnt')
plt.plot(errorKE_benchmark_log.detach().numpy(), 'r-', label='log')
plt.plot(errorKE_benchmark_F.detach().numpy(), 'g-', label='Frobenius')
plt.grid()
plt.legend()
plt.show()
